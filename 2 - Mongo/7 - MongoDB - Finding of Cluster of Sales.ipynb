# %% [raw]
# --: MongoDB - User Story - 1 :-
#
# For a specified Manufacturer, the company needs information about end users who are buying their products, which geolocation segments they are coming from? If possible, they need different clusters where they can do more business?

# %%
############################# Importing all req. libreries ############################################
import ipywidgets as ipw
from pymongo import MongoClient
from mongoengine import connect,Document,fields,disconnect
import pandas as pd
from mpl_toolkits.basemap import Basemap
import matplotlib
# %matplotlib qt
import matplotlib.pyplot as plt
from bson import ObjectId
from IPython.display import display
from IPython.display import Image


############################# Selecting the Entity IDs  ############################################
ids = pd.read_excel("IDs.xlsx")


client = MongoClient("mongodb://localhost:27017")
database = client["SCM_DB"]
connect(db="SCM_DB")
#disconnect()

Mobile_Spec = ipw.Dropdown(
    options=list(ids["MobileSpceIds"]),
    description = "Select Mobile - ", )
Manuf_id = ipw.Dropdown(
    options=list(ids["Manufacturer"].dropna()),
    description = "Manufacturer - ", )
ipw.HBox([Mobile_Spec , Manuf_id])
# Out:
# HBox(children=(Dropdown(description='Select Mobile - ', options=('NONE', '5e4acd2b430f6652feafa939', '5e4acd2b…

# %%
Manuf_id = Manuf_id.value
Mobile_Spec = Mobile_Spec.value

# %%
############################# Printing the Selected Manufacturer  ######################################
collection = database["Top_Level_Assembly_Colleciton"]
cruser = collection.find({"Manufacturer_ID": Manuf_id})
for doc in cruser: 
    doc = doc["Manufacturer locaiton"]
    display(pd.Series(doc,index=doc.keys()))
    break
# Out:
# Manufacturer Name        Neutral Sarun GmbH
# Manufacturer Address     Kurt-Leucht-Weg 11
# Manufacturer City                   Numberg
# Manufacturer Country                Germany
# Manufacturer ZIP Code                 90471
# dtype: object

# %%
############################# Printing the Selected Mobile Specifications  ##############################
collection = database["Mobile_Specifications"]
cruser = collection.find({"_id": ObjectId(Mobile_Spec)})
for doc in cruser: 
    display(pd.Series(doc,index=doc.keys()))
    break
    
collection = database["Mobile_Images"]
cruser = collection.find({"mob_ds_id": ObjectId(Mobile_Spec)})
for doc in cruser: 
    class mobile(Document):
        meta = {"collection" : "Mobile_Images"}
        mob_ds_id= fields.ObjectIdField(requried=True)
        mob_name = fields.StringField(requried=True)
        image = fields.ImageField(thumbnail_size=(150,150,False))
    mob = mobile.objects(mob_ds_id = doc["mob_ds_id"]).first()
    display(Image(mob.image.read()))
    break
# Out:
# _id                                              5e4acd2b430f6652feafa944
# Mobile_Name                                        Samsung Galaxy J2 Core
# Mobile_Type                                                        Galaxy
# network_technology                                   [GSM ,  HSPA ,  LTE]
# 2G_bands                    [GSM 850 , GSM  900 , GSM  1800 , GSM  1900 ]
# 3G_bands                [HSDPA 850 , HSDPA  900 , HSDPA  1900 , HSDPA ...
# 4G_bands                [LTE band 1(2100), LTE band  2(1900), LTE band...
# network_speed           [ "HSPA 42.2/5.76 Mbps","  LTE-A (2CA) Cat6 30...
# GPRS                                                                 True
# EDGE                                                                 True
# announced                                             2017-02-01 00:00:00
# status                                    Available. Released 2017  April
# SIM                                                              Nano-SIM
# display_type              Super AMOLED capacitive touchscreen  16M colors
# display_resolution 1                                          9.7 inches
# display_size 1                                        1536 x 2048 pixels
# OS                                                   Android 7.0 (nougat)
# CPU                          Quad-core (2x2.15 GHz Kryo & 2x1.6 GHz Kryo)
# Chipset                                   Qualcomm MSM8996 Snapdragon 820
# GPU                                                            Adreno 530
# memory_card                        microSD  up to 256 GB (dedicated slot)
# internal_memory                                                     32 GB
# RAM                                                              4 GB RAM
# primary_camera             [13 MP,  f/1.9,  27mm,  autofocus,  LED flash]
# secondary_camera                            [5 MP,  f/2.2,  23mm,  1080p]
# loud_speaker                        yes with stereo speakers (4 speakers)
# audio_jack                                                           True
# WLAN                    [Wi-Fi 802.11 a/b/g/n/ac,  dual-band,  Wi-Fi D...
# bluetooth                                               [4.2,  A2DP,  LE]
# GPS                                    yes with A-GPS GLONASS BDS GALILEO
# radio                                                                  no
# USB                     [3.1,  Type-C 1.0 reversible connector; magnet...
# sensors                 [Fingerprint (front-mounted),  accelerometer, ...
# battery                                    non-removable 6000 mAh battery
# colors                                                    [White,  black]
# approx_price_EUR                                                      750
# Size                       {'Height': 237.3, 'Width': 169, 'Depth': 6.65}
# dtype: object

# %%
########################################## Mongo DB  #####################################################
collection = database["Retailer_orders_DB"]
pipeline_1 = [
    {
        u"$unwind": {
            u"path": u"$Order_Items_List"
        }
    }, 
    {
        u"$project": {
            u"_id": 0.0,
            u"End_User_ID": u"$End_User_ID",
            u"Mobile IMEI": u"$Order_Items_List",
            u"End User Address": u"$End User Address"
        }
    }, 
    {
        u"$out": u"temp"
    }
]

cursor = collection.aggregate(
    pipeline_1, 
    allowDiskUse = False
)
print("Temp Collection Created")
# Out:
# Temp Collection Created

# %%
collection = database["Top_Level_Assembly_Colleciton"]
pipeline_2 = [
    {
        u"$match": {
            u"Manufacturer_ID": Manuf_id,
            u"Mobile Spec Reference": Mobile_Spec
        }
    }, 
    {
        u"$project": {
            u"_id": 0.0,
            u"Mobile IMEI": u"$Mobile IMEI"
        }
    }, 
    {
        u"$lookup": {
            u"from": u"temp",
            u"localField": u"Mobile IMEI",
            u"foreignField": u"Mobile IMEI",
            u"as": u"k"
        }
    }, 
    {
        u"$unwind": {
            u"path": u"$k"
        }
    }, 
    {
        u"$project": {
            u"End_User_ID": u"$k.End_User_ID",
            u"End User Address": u"$k.End User Address"
        }
    }, 
    {
        u"$lookup": {
            u"from": u"Geolocations",
            u"localField": u"End User Address",
            u"foreignField": u"Address",
            u"as": u"Geolocation"
        }
    }, 
    {
        u"$unwind": {
            u"path": u"$Geolocation"
        }
    }, 
    {
        u"$project": {
            u"User_ID": u"$End_User_ID",
            u"Latitude": u"$Geolocation.Latitude",
            u"Longitude": u"$Geolocation.Longitude"
        }
    }
]
cursor = collection.aggregate(
    pipeline_2, 
    allowDiskUse = False
)
lats = []
lons = []
try:
    for doc in cursor:
        print(doc)
        lats.append(doc["Latitude"])
        lons.append(doc["Longitude"])
finally:
    client.close()
# Out:
# {'User_ID': 'User_US_182', 'Latitude': 41.8619, 'Longitude': -70.9411}
# {'User_ID': 'User_GER_392', 'Latitude': 47.5161161, 'Longitude': 10.2808617}
# {'User_ID': 'User_US_004', 'Latitude': -3.390607, 'Longitude': -57.71385}
# {'User_ID': 'User_GER_049', 'Latitude': 48.2946154, 'Longitude': 8.5765805}
# {'User_ID': 'User_SP_097', 'Latitude': 41.7495, 'Longitude': -74.0809}
# {'User_ID': 'User_SP_684', 'Latitude': 51.6596767, 'Longitude': 9.6384529}
# {'User_ID': 'User_SP_263', 'Latitude': 32.9791, 'Longitude': -86.0358}
# {'User_ID': 'User_US_532', 'Latitude': 53.529977, 'Longitude': 8.112526}
# {'User_ID': 'User_GER_099', 'Latitude': 42.016, 'Longitude': -95.3528}
# {'User_ID': 'User_US_110', 'Latitude': 48.5441917, 'Longitude': 12.1468532}
# {'User_ID': 'User_US_125', 'Latitude': -2.632757, 'Longitude': -56.732798}
# {'User_ID': 'User_US_314', 'Latitude': 51.848277, 'Longitude': 12.229065}
# {'User_ID': 'User_SP_095', 'Latitude': 33.1483, 'Longitude': -95.9532}
# {'User_ID': 'User_GER_626', 'Latitude': 39.05391, 'Longitude': -7.891556}
# {'User_ID': 'User_US_235', 'Latitude': 37.319152, 'Longitude': -8.803305}
# {'User_ID': 'User_GER_174', 'Latitude': 38.749, 'Longitude': -90.2949}
# {'User_ID': 'User_SP_654', 'Latitude': -5.340677, 'Longitude': -49.095483}
# {'User_ID': 'User_SP_167', 'Latitude': -30.033333, 'Longitude': -51.2}
# {'User_ID': 'User_SP_530', 'Latitude': -20.076647, 'Longitude': -44.574877}
# {'User_ID': 'User_US_265', 'Latitude': -21.242429, 'Longitude': -44.997852}
# {'User_ID': 'User_US_442', 'Latitude': 47.9160569, 'Longitude': 7.7003244}
# {'User_ID': 'User_SP_233', 'Latitude': 37.474317, 'Longitude': -7.472282}
# {'User_ID': 'User_SP_208', 'Latitude': 35.2104, 'Longitude': -106.589}

# %%
####################### Visulizing the results in Map ###################################################
m = Basemap(projection='mill',
                resolution='l') 

m.drawcoastlines()
m.drawcountries(linewidth=0.1)

for lat , lon in zip(lats,lons):
    x,y = m.projtran(lon,lat)
    m.plot(x,y,'c*',markersize=15)
plt.show()
# Out:
# C:\Users\anilk\Anaconda3\envs\Final\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\anilk\Anaconda3\envs\Final\lib\site-packages\ipykernel_launcher.py:6: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
